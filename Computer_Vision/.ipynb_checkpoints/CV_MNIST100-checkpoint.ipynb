# %%
import numpy as np
from matplotlib import pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from sklearn.metrics import accuracy_score
import time
import warnings
warnings.filterwarnings('ignore')
import progressbar
from keras.datasets import mnist

# %%
df = np.load("mnist_compressed.npz")
train_images = df['train_images']
train_labels = df['train_labels']
test_images = df['test_images']
test_labels = df['test_labels']

# %%
(train_images_1, train_labels_1), (test_images_1, test_labels_1) = mnist.load_data()

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
print(train_images_1.shape)
print(train_labels_1.shape)
print(test_images_1.shape)
print(test_labels_1.shape)
# Out:
# (60000, 28, 56)
# (60000,)
# (10000, 28, 56)
# (10000,)
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
for i in range(0,3):
    n = random.randint(0,59999)
    plt.imshow(train_images[n], interpolation='nearest')
    plt.show()

# %%
layers = [tf.keras.Input(shape=(28,28, 1)), Conv2D(8,5), MaxPool2D(), Conv2D(8,3), MaxPool2D(), Flatten(), Dense(1000, activation='relu'), Dense(10, activation= 'softmax')]
model = tf.keras.models.Sequential(layers)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 8)         208
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 8)         584
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 8)           0
#  g2D)
#
#  flatten (Flatten)           (None, 200)               0
#
#  dense (Dense)               (None, 1000)              201000
#
#  dense_1 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 211802 (827.35 KB)
# Trainable params: 211802 (827.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
n_epochs = 10
model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images_1, train_labels_1, epochs=n_epochs, validation_data = (test_images_1, test_labels_1))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 36s 18ms/step - loss: 0.5861 - accuracy: 0.9327 - val_loss: 0.1529 - val_accuracy: 0.9617
# Epoch 2/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.1129 - accuracy: 0.9703 - val_loss: 0.0912 - val_accuracy: 0.9732
# Epoch 3/10
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.1057 - accuracy: 0.9733 - val_loss: 0.1437 - val_accuracy: 0.9684
# Epoch 4/10
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0906 - accuracy: 0.9768 - val_loss: 0.1328 - val_accuracy: 0.9699
# Epoch 5/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0860 - accuracy: 0.9786 - val_loss: 0.0992 - val_accuracy: 0.9769
# Epoch 6/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0756 - accuracy: 0.9818 - val_loss: 0.1024 - val_accuracy: 0.9799
# Epoch 7/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0717 - accuracy: 0.9824 - val_loss: 0.1007 - val_accuracy: 0.9786
# Epoch 8/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0711 - accuracy: 0.9837 - val_loss: 0.0861 - val_accuracy: 0.9797
# Epoch 9/10
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0653 - accuracy: 0.9851 - val_loss: 0.1318 - val_accuracy: 0.9767
# Epoch 10/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0682 - accuracy: 0.9867 - val_loss: 0.1130 - val_accuracy: 0.9769

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(np.arange(1, n_epochs+1), history.history['loss'], label='Train set')
plt.plot(np.arange(1, n_epochs+1), history.history['val_loss'], label='Test set')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(np.arange(1, n_epochs+1), history.history['accuracy'], label='Train set')
plt.plot(np.arange(1, n_epochs+1), history.history['val_accuracy'], label='Test set')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
print(f"\nAccuracy on the final epoch of training was {100*history.history['accuracy'][-1]:0.2f}%")
# Out:
# Accuracy on the final epoch of training was 98.67%

# %%
def vertLine(index):
    test = train_images[index]
    i, j = np.ogrid[(*map(slice, test.shape),)]
    points = np.argwhere((test>0))
    
    for i in range(28):
        splitL = True
        splitR = True
        for point in points:
            if point[1] == 28-i:
                splitL = False
            if point[i] == 28+i:
                splitR = False
        if splitL:
            return 28-i
        elif splitR:
            return 28+i

# %%
n_trials = len(train_images)
widgets = [progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA(), ]
bar = progressbar.ProgressBar(maxval=(n_trials-1), widgets = widgets).start()

preds = []
for i in range(n_trials):
    dim = vertLine(i)
    bar.update(i)
    if dim == -1:
        print("Non seperable at: " + str(i))
        plt.imshow(train_images[i], interpolation='nearest')
        plt.show()
    else:
        ten = train_images[i][:,:dim].reshape(1,28,28)
        one = train_images[i][:,dim:].reshape(1,28,28)
        tens = np.argmax(model(ten))
        one = np.argmax(model(one))
        preds.append(10*tens + one)
# Out:
#  99% |######################################################## | ETA:   0:00:00
# [64,
#  18,
#  72,
#  14,
#  17,
#  78,
#  60,
#  46,
#  51,
#  43,
#  18,
#  24,
#  88,
#  97,
#  81,
#  77,
#  70,
#  42,
#  32,
#  77,
#  3,
#  21,
#  37,
#  10,
#  16,
#  11,
#  9,
#  91,
#  59,
#  77,
#  36,
#  41,
#  30,
#  57,
#  58,
#  68,
#  11,
#  73,
#  60,
#  26,
#  86,
#  83,
#  20,
#  74,
#  97,
#  35,
#  63,
#  95,
#  58,
#  93,
#  76,
#  32,
#  71,
#  15,
#  65,
#  73,
#  36,
#  61,
#  53,
#  39,
#  55,
#  24,
#  64,
#  60,
#  48,
#  44,
#  0,
#  22,
#  32,
#  64,
#  54,
#  56,
#  92,
#  99,
#  24,
#  55,
#  21,
#  76,
#  20,
#  92,
#  81,
#  90,
#  47,
#  32,
#  53,
#  62,
#  29,
#  77,
#  93,
#  49,
#  59,
#  9,
#  98,
#  91,
#  98,
#  89,
#  17,
#  36,
#  75,
#  34,
#  30,
#  69,
#  19,
#  8,
#  35,
#  0,
#  75,
#  2,
#  18,
#  87,
#  30,
#  8,
#  69,
#  55,
#  76,
#  98,
#  32,
#  22,
#  42,
#  55,
#  40,
#  68,
#  25,
#  95,
#  57,
#  51,
#  72,
#  48,
#  8,
#  59,
#  28,
#  69,
#  24,
#  10,
#  5,
#  0,
#  65,
#  59,
#  68,
#  34,
#  42,
#  52,
#  63,
#  8,
#  27,
#  75,
#  1,
#  23,
#  46,
#  37,
#  76,
#  17,
#  99,
#  27,
#  68,
#  7,
#  36,
#  96,
#  40,
#  15,
#  86,
#  27,
#  73,
#  52,
#  90,
#  57,
#  5,
#  39,
#  64,
#  91,
#  91,
#  83,
#  64,
#  98,
#  49,
#  97,
#  87,
#  71,
#  56,
#  14,
#  1,
#  42,
#  95,
#  55,
#  46,
#  29,
#  44,
#  53,
#  61,
#  2,
#  41,
#  16,
#  27,
#  25,
#  49,
#  27,
#  59,
#  12,
#  88,
#  24,
#  65,
#  45,
#  4,
#  91,
#  29,
#  35,
#  40,
#  25,
#  1,
#  45,
#  22,
#  1,
#  3,
#  85,
#  73,
#  94,
#  46,
#  20,
#  95,
#  64,
#  41,
#  9,
#  51,
#  75,
#  4,
#  34,
#  70,
#  56,
#  30,
#  32,
#  92,
#  71,
#  7,
#  13,
#  30,
#  32,
#  96,
#  17,
#  19,
#  34,
#  20,
#  67,
#  96,
#  83,
#  69,
#  76,
#  11,
#  87,
#  54,
#  52,
#  88,
#  74,
#  0,
#  18,
#  61,
#  31,
#  11,
#  53,
#  86,
#  28,
#  62,
#  56,
#  8,
#  40,
#  20,
#  42,
#  48,
#  61,
#  51,
#  97,
#  22,
#  28,
#  25,
#  12,
#  1,
#  89,
#  79,
#  26,
#  69,
#  45,
#  10,
#  21,
#  70,
#  87,
#  0,
#  39,
#  92,
#  1,
#  44,
#  96,
#  56,
#  53,
#  1,
#  92,
#  67,
#  79,
#  24,
#  22,
#  24,
#  21,
#  95,
#  48,
#  54,
#  63,
#  65,
#  34,
#  9,
#  87,
#  3,
#  73,
#  27,
#  35,
#  39,
#  37,
#  61,
#  40,
#  74,
#  93,
#  29,
#  40,
#  18,
#  64,
#  34,
#  68,
#  33,
#  8,
#  12,
#  35,
#  5,
#  40,
#  88,
#  62,
#  30,
#  66,
#  95,
#  83,
#  24,
#  21,
#  85,
#  72,
#  56,
#  19,
#  75,
#  17,
#  99,
#  25,
#  7,
#  83,
#  19,
#  23,
#  98,
#  2,
#  80,
#  97,
#  96,
#  35,
#  83,
#  59,
#  12,
#  90,
#  46,
#  1,
#  11,
#  15,
#  57,
#  82,
#  33,
#  46,
#  72,
#  87,
#  93,
#  0,
#  14,
#  35,
#  8,
#  15,
#  60,
#  87,
#  50,
#  17,
#  89,
#  50,
#  68,
#  74,
#  18,
#  95,
#  57,
#  37,
#  79,
#  80,
#  26,
#  80,
#  87,
#  55,
#  4,
#  24,
#  0,
#  93,
#  5,
#  2,
#  79,
#  69,
#  58,
#  0,
#  3,
#  37,
#  57,
#  24,
#  3,
#  42,
#  26,
#  38,
#  0,
#  97,
#  4,
#  74,
#  32,
#  12,
#  73,
#  33,
#  56,
#  93,
#  51,
#  45,
#  81,
#  18,
#  80,
#  83,
#  34,
#  22,
#  19,
#  55,
#  39,
#  0,
#  33,
#  13,
#  27,
#  45,
#  34,
#  5,
#  74,
#  10,
#  90,
#  37,
#  81,
#  37,
#  76,
#  54,
#  7,
#  19,
#  14,
#  17,
#  97,
#  64,
#  91,
#  38,
#  17,
#  29,
#  13,
#  71,
#  2,
#  11,
#  63,
#  83,
#  34,
#  81,
#  74,
#  77,
#  2,
#  26,
#  5,
#  14,
#  34,
#  23,
#  51,
#  97,
#  2,
#  18,
#  81,
#  10,
#  69,
#  36,
#  38,
#  29,
#  60,
#  21,
#  8,
#  5,
#  63,
#  72,
#  37,
#  18,
#  9,
#  25,
#  26,
#  36,
#  16,
#  44,
#  51,
#  19,
#  30,
#  17,
#  78,
#  50,
#  97,
#  68,
#  2,
#  21,
#  26,
#  24,
#  67,
#  88,
#  88,
#  27,
#  91,
#  70,
#  49,
#  7,
#  50,
#  32,
#  79,
#  4,
#  0,
#  27,
#  14,
#  11,
#  68,
#  24,
#  53,
#  46,
#  26,
#  37,
#  96,
#  91,
#  66,
#  71,
#  19,
#  86,
#  22,
#  47,
#  83,
#  86,
#  86,
#  26,
#  19,
#  18,
#  66,
#  77,
#  73,
#  98,
#  76,
#  66,
#  75,
#  86,
#  66,
#  68,
#  22,
#  2,
#  73,
#  33,
#  77,
#  14,
#  47,
#  94,
#  13,
#  22,
#  0,
#  56,
#  74,
#  88,
#  8,
#  88,
#  47,
#  14,
#  64,
#  78,
#  53,
#  78,
#  10,
#  16,
#  26,
#  62,
#  85,
#  25,
#  81,
#  91,
#  53,
#  51,
#  87,
#  93,
#  81,
#  81,
#  57,
#  11,
#  68,
#  18,
#  20,
#  27,
#  5,
#  27,
#  6,
#  78,
#  6,
#  43,
#  92,
#  91,
#  71,
#  17,
#  78,
#  97,
#  51,
#  85,
#  45,
#  68,
#  90,
#  16,
#  95,
#  23,
#  11,
#  2,
#  64,
#  70,
#  38,
#  77,
#  82,
#  19,
#  72,
#  99,
#  64,
#  26,
#  30,
#  23,
#  7,
#  29,
#  89,
#  52,
#  54,
#  43,
#  95,
#  52,
#  54,
#  60,
#  92,
#  24,
#  17,
#  50,
#  2,
#  7,
#  66,
#  32,
#  8,
#  5,
#  22,
#  3,
#  66,
#  74,
#  28,
#  54,
#  78,
#  37,
#  62,
#  38,
#  36,
#  92,
#  73,
#  3,
#  25,
#  16,
#  24,
#  44,
#  87,
#  42,
#  86,
#  42,
#  13,
#  23,
#  60,
#  94,
#  92,
#  81,
#  92,
#  69,
#  27,
#  85,
#  48,
#  95,
#  28,
#  83,
#  91,
#  8,
#  21,
#  77,
#  89,
#  71,
#  91,
#  86,
#  69,
#  58,
#  45,
#  19,
#  15,
#  63,
#  35,
#  47,
#  31,
#  9,
#  85,
#  57,
#  18,
#  46,
#  28,
#  78,
#  89,
#  67,
#  0,
#  40,
#  2,
#  96,
#  87,
#  72,
#  7,
#  96,
#  54,
#  47,
#  16,
#  56,
#  97,
#  95,
#  32,
#  48,
#  3,
#  24,
#  4,
#  90,
#  32,
#  10,
#  53,
#  41,
#  3,
#  2,
#  87,
#  2,
#  37,
#  44,
#  94,
#  38,
#  71,
#  13,
#  40,
#  12,
#  34,
#  91,
#  48,
#  32,
#  90,
#  27,
#  1,
#  20,
#  94,
#  45,
#  3,
#  84,
#  13,
#  97,
#  97,
#  84,
#  18,
#  52,
#  48,
#  22,
#  4,
#  52,
#  32,
#  69,
#  81,
#  37,
#  89,
#  15,
#  26,
#  93,
#  90,
#  92,
#  85,
#  83,
#  48,
#  81,
#  60,
#  24,
#  45,
#  11,
#  18,
#  43,
#  91,
#  13,
#  10,
#  67,
#  86,
#  44,
#  43,
#  28,
#  93,
#  65,
#  35,
#  17,
#  9,
#  47,
#  79,
#  0,
#  11,
#  41,
#  56,
#  13,
#  85,
#  55,
#  32,
#  92,
#  41,
#  88,
#  25,
#  71,
#  42,
#  17,
#  47,
#  34,
#  95,
#  19,
#  74,
#  4,
#  20,
#  78,
#  72,
#  2,
#  66,
#  81,
#  48,
#  28,
#  8,
#  7,
#  62,
#  67,
#  94,
#  15,
#  75,
#  6,
#  10,
#  33,
#  29,
#  84,
#  93,
#  94,
#  77,
#  18,
#  16,
#  28,
#  21,
#  52,
#  12,
#  20,
#  36,
#  76,
#  87,
#  2,
#  87,
#  48,
#  31,
#  4,
#  36,
#  71,
#  52,
#  5,
#  10,
#  75,
#  19,
#  13,
#  92,
#  10,
#  11,
#  94,
#  61,
#  84,
#  20,
#  92,
#  48,
#  3,
#  81,
#  20,
#  97,
#  95,
#  42,
#  58,
#  10,
#  98,
#  50,
#  28,
#  89,
#  97,
#  77,
#  45,
#  85,
#  52,
#  98,
#  49,
#  26,
#  73,
#  36,
#  4,
#  84,
#  39,
#  86,
#  81,
#  70,
#  51,
#  84,
#  42,
#  40,
#  18,
#  75,
#  93,
#  69,
#  6,
#  53,
#  9,
#  45,
#  96,
#  61,
#  91,
#  85,
#  2,
#  59,
#  36,
#  36,
#  29,
#  41,
#  31,
#  40,
#  84,
#  10,
#  93,
#  94,
#  92,
#  68,
#  59,
#  78,
#  92,
#  97,
#  28,
#  77,
#  21,
#  86,
#  86,
#  80,
#  17,
#  60,
#  29,
#  90,
#  26,
#  5,
#  82,
#  54,
#  22,
#  15,
#  35,
#  96,
#  78,
#  79,
#  1,
#  39,
#  44,
#  74,
#  67,
#  38,
#  68,
#  13,
#  59,
#  1,
#  69,
#  74,
#  41,
#  23,
#  10,
#  69,
#  70,
#  68,
#  21,
#  89,
#  44,
#  91,
#  76,
#  4,
#  78,
#  95,
#  3,
#  71,
#  42,
#  10,
#  13,
#  86,
#  55,
#  90,
#  23,
#  ...]

# %%
accuracy_score(train_labels, preds)
# Out:
# 0.9765833333333334
