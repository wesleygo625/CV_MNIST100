# %%
import numpy as np
from matplotlib import pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from sklearn.cluster import KMeans
import time
import warnings
warnings.filterwarnings('ignore')
import progressbar
from keras.datasets import mnist

# %%
df = np.load("mnist_compressed.npz")
train_images = df['train_images']
train_labels = df['train_labels']
test_images = df['test_images']
test_labels = df['test_labels']

# %%
(train_images_1, train_labels_1), (test_images_1, test_labels_1) = mnist.load_data()

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
print(train_images_1.shape)
print(train_labels_1.shape)
print(test_images_1.shape)
print(test_labels_1.shape)
# Out:
# (60000, 28, 56)
# (60000,)
# (10000, 28, 56)
# (10000,)
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
for i in range(0,3):
    n = random.randint(0,59999)
    plt.imshow(train_images[n], interpolation='nearest')
    plt.show()

# %%
layers = [tf.keras.Input(shape=(28,28,1)), Conv2D(8,5), MaxPool2D(), Conv2D(8,3), MaxPool2D(), Flatten(), Dense(1000, activation='relu'), Dense(100, activation= 'softmax')]
model = tf.keras.models.Sequential(layers)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 24, 24, 8)         208
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 8)         0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 8)         584
#
#  max_pooling2d_3 (MaxPoolin  (None, 5, 5, 8)           0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 200)               0
#
#  dense_2 (Dense)             (None, 1000)              201000
#
#  dense_3 (Dense)             (None, 100)               100100
#
# =================================================================
# Total params: 301892 (1.15 MB)
# Trainable params: 301892 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
n_epochs = 10
model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images_1, train_labels_1, epochs=n_epochs, validation_data = (test_images_1, test_labels_1))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 19s 10ms/step - loss: 0.1090 - accuracy: 0.9747 - val_loss: 0.1243 - val_accuracy: 0.9741
# Epoch 2/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0831 - accuracy: 0.9796 - val_loss: 0.1061 - val_accuracy: 0.9715
# Epoch 3/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0830 - accuracy: 0.9798 - val_loss: 0.0871 - val_accuracy: 0.9789
# Epoch 4/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0693 - accuracy: 0.9833 - val_loss: 0.1085 - val_accuracy: 0.9818
# Epoch 5/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0608 - accuracy: 0.9860 - val_loss: 0.2160 - val_accuracy: 0.9616
# Epoch 6/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0702 - accuracy: 0.9841 - val_loss: 0.1919 - val_accuracy: 0.9762
# Epoch 7/10
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.0642 - accuracy: 0.9855 - val_loss: 0.1324 - val_accuracy: 0.9814
# Epoch 8/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0772 - accuracy: 0.9851 - val_loss: 0.1313 - val_accuracy: 0.9791
# Epoch 9/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0587 - accuracy: 0.9878 - val_loss: 0.1057 - val_accuracy: 0.9822
# Epoch 10/10
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0695 - accuracy: 0.9867 - val_loss: 0.1728 - val_accuracy: 0.9783

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(np.arange(1, n_epochs+1), history.history['loss'], label='Train set')
plt.plot(np.arange(1, n_epochs+1), history.history['val_loss'], label='Test set')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(np.arange(1, n_epochs+1), history.history['accuracy'], label='Train set')
plt.plot(np.arange(1, n_epochs+1), history.history['val_accuracy'], label='Test set')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
print(f"\nAccuracy on the final epoch of training was {100*history.history['accuracy'][-1]:0.2f}%")
# Out:
# Accuracy on the final epoch of training was 98.67%

# %%
def cluster(index):
    test = train_images[index]
    i, j = np.ogrid[(*map(slice, test.shape),)]
    points = np.argwhere((test>0))
    clusterer = KMeans(n_clusters=2, n_init='auto')
    clusters = clusterer.fit_predict(test)
    return checkLine(points, clusters)

# %%
def checkLine(test, clusters):
    for i in range(56):
        c = -1
        for j in range(len(test[0])):
            if test[j][0] == i:
                if (c == -1) or (c == clusters[j]):
                    c = clusters[j]
                else:
                    return 0
    return 1

# %%
n_trials = 59999
widgets = [progressbar.Percentage(), " ", progressbar.Bar(), " ", progressbar.ETA(), ]
bar = progressbar.ProgressBar(maxval=(n_trials-1), widgets = widgets).start()

for i in range(n_trials):
    if cluster(i) == 0:
        print("Cannot linearly discriminate: " + str(i))
    bar.update(i)
# Out:
#   2% |#                                                         | ETA:  1:06:12
# Cannot linearly discriminate: 1340
#  48% |############################                              | ETA:  0:37:07
# Cannot linearly discriminate: 29025
#  95% |#######################################################   | ETA:  0:03:35
# Cannot linearly discriminate: 57046
#  99% |######################################################### | ETA:  0:00:00

# %%
plt.imshow(train_images[1339], interpolation='nearest')
plt.show()
